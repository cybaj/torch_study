# %%
import torch

# %%
torch.__version__
# Out:
# '1.5.0+cpu'

# %% [markdown]
# 설치 스크립트
# ```
# !pip install torchviz
# ```

# %%
from torchviz import make_dot, make_dot_from_trace

# %%
import torch.nn as nn
from torch.autograd import Variable

# %%
model = nn.Sequential()
model.add_module('W0', nn.Linear(8,16))
model.add_module('tanh', nn.Tanh())
model.add_module('W1', nn.Linear(16,1))

# %%
x = Variable(torch.rand(1,8))
x
# Out:
# tensor([[0.2720, 0.0134, 0.5643, 0.0087, 0.6676, 0.2577, 0.0950, 0.6979]])

# %%
y = model(x)

# %%
make_dot(y.mean(), params=dict(model.named_parameters()))

# %%
help(make_dot_from_trace)
# Out:
# Help on function make_dot_from_trace in module torchviz.dot:
#
# make_dot_from_trace(trace)
#     Produces graphs of torch.jit.trace outputs
#
#     Example:
#     >>> trace, = torch.jit.trace(model, args=(x,))
#     >>> dot = make_dot_from_trace(trace)

# %%
trace = torch.jit.trace(model, [x,])

# %%
dot = make_dot_from_trace(trace)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-4da3517a28eb> in <module>
# ----> 1 dot = make_dot_from_trace(trace)
#
# /opt/conda/lib/python3.7/site-packages/torchviz/dot.py in make_dot_from_trace(trace)
#     125     # from tensorboardX
#     126     if LooseVersion(torch.__version__) >= LooseVersion("0.4.1"):
# --> 127         torch.onnx._optimize_trace(trace, torch._C._onnx.OperatorExportTypes.ONNX_ATEN_FALLBACK)
#     128     elif LooseVersion(torch.__version__) >= LooseVersion("0.4"):
#     129         torch.onnx._optimize_trace(trace, False)
#
# /opt/conda/lib/python3.7/site-packages/torch/onnx/__init__.py in _optimize_trace(graph, operator_export_type)
#     181 def _optimize_trace(graph, operator_export_type):
#     182     from torch.onnx import utils
# --> 183     return utils._optimize_graph(graph, operator_export_type)
#     184
#     185
#
# /opt/conda/lib/python3.7/site-packages/torch/onnx/utils.py in _optimize_graph(graph, operator_export_type, _disable_torch_constant_prop, fixed_batch_size, params_dict)
#      91 def _optimize_graph(graph, operator_export_type, _disable_torch_constant_prop=False, fixed_batch_size=False, params_dict=None):
#      92     # Inline everyting
# ---> 93     torch._C._jit_pass_inline(graph)
#      94
#      95     # Remove fork/wait nodes
#
# TypeError: _jit_pass_inline(): incompatible function arguments. The following argument types are supported:
#     1. (arg0: torch::jit::Graph) -> None
#
# Invoked with: Sequential(
#   original_name=Sequential
#   (W0): Linear(original_name=Linear)
#   (tanh): Tanh(original_name=Tanh)
#   (W1): Linear(original_name=Linear)
# )
